# %%
# %pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.1/122.1 kB 3.8 MB/s eta 0:00:00
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (912 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.2/912.2 kB 4.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (490 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.1/490.1 kB 4.4 MB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting typer<0.8.0,>=0.3.0
#   Using cached typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting pathy>=0.10.0
#   Using cached pathy-0.10.1-py3-none-any.whl (48 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.8 MB/s eta 0:00:00
# Collecting tqdm<5.0.0,>=4.38.0
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting numpy>=1.15.0
#   Using cached numpy-1.24.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Collecting requests<3.0.0,>=2.13.0
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: jinja2 in /home/anarok/Playground/Raj-IT-Hacks/venv/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /home/anarok/Playground/Raj-IT-Hacks/venv/lib/python3.11/site-packages (from spacy) (62.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/anarok/Playground/Raj-IT-Hacks/venv/lib/python3.11/site-packages (from spacy) (23.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting typing-extensions>=4.2.0
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.3/197.3 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /home/anarok/Playground/Raj-IT-Hacks/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 3.6 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.0.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/anarok/Playground/Raj-IT-Hacks/venv/lib/python3.11/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/anarok/Playground/Raj-IT-Hacks/venv/lib64/python3.11/site-packages (from jinja2->spacy) (2.1.2)
# Installing collected packages: cymem, wasabi, urllib3, typing-extensions, typer, tqdm, spacy-loggers, spacy-legacy, smart-open, numpy, murmurhash, langcodes, charset-normalizer, certifi, catalogue, srsly, requests, pydantic, preshed, pathy, blis, confection, thinc, spacy
# Successfully installed blis-0.7.9 catalogue-2.0.8 certifi-2022.12.7 charset-normalizer-3.1.0 confection-0.0.4 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 numpy-1.24.2 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.6 requests-2.28.2 smart-open-6.3.0 spacy-3.5.1 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 thinc-8.1.9 tqdm-4.65.0 typer-0.7.0 typing-extensions-4.5.0 urllib3-1.26.15 wasabi-1.1.1
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install yake 
import yake
# Out:
# Collecting yake
#   Using cached yake-0.4.8-py2.py3-none-any.whl (60 kB)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: click>=6.0 in /home/anarok/Playground/Raj-IT-Hacks/venv/lib/python3.11/site-packages (from yake) (8.1.3)
# Requirement already satisfied: numpy in /home/anarok/Playground/Raj-IT-Hacks/venv/lib64/python3.11/site-packages (from yake) (1.24.2)
# Collecting segtok
#   Using cached segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting networkx
#   Using cached networkx-3.0-py3-none-any.whl (2.0 MB)
# Collecting jellyfish
#   Using cached jellyfish-0.9.0-cp311-cp311-linux_x86_64.whl
# Collecting regex
#   Using cached regex-2022.10.31-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
# Installing collected packages: tabulate, regex, networkx, jellyfish, segtok, yake
# Successfully installed jellyfish-0.9.0 networkx-3.0 regex-2022.10.31 segtok-1.5.11 tabulate-0.9.0 yake-0.4.8
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
kw_extractor = yake.KeywordExtractor()

# %%
 text = """spaCy is an open-source software library for advanced natural language processing, written in the programming languages Python and Cython. The library is published under the MIT license and its main developers are Matthew Honnibal and Ines Montani, the founders of the software company Explosion.""".lower()

# %%
 language = "en"

# %% [markdown]
# max_ngram_size = 3
# deduplication_threshold = 0.9
# numOfKeywords = 20
# custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
# keywords = custom_kw_extractor.extract_keywords(text)
# for kw in keywords:
#   print(kw)

# %%
max_ngram_size = 3
deduplication_threshold = 0.9
numOfKeywords = 20
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
keywords = custom_kw_extractor.extract_keywords(text)
for i, kw in enumerate(keywords): 
  keywords[i] = kw[0]

print(keywords)
# Out:
# ['natural language processing', 'advanced natural language', 'programming languages python', 'open-source software library', 'python and cython', 'language processing', 'advanced natural', 'natural language', 'programming languages', 'languages python', 'software company explosion', 'open-source software', 'software library', 'library for advanced', 'software company', 'spacy', 'processing', 'written', 'cython', 'ines montani']

# %%
word = input()
print(word)

import nltk
# for sent in range(len(keywords)):
#   l = keywords[sent].split(' ')
#   for word in l:

for entity in keywords:
  for val in entity:
    score = nltk.edit_distance(word, val, transpositions=False)
    print(f'Score: {score}')
    if score <= 1: 
    # and (ispresent(word, val) or ispresent(val, word)):
      print(word, entity)
# Out:
# i code in cython and python
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 27
# Score: 27
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 27
# Score: 26
# Score: 27
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26
# Score: 26

# %%
#calc of premium : 
premium_dict = {}
for startup in listofstartups:
  roi = ((total_invested_money_startup - revenue_generated)/total_invested_money_startup)
  premium_dict[startup] = roi

premium_percent = 1000
if (roi == -1):
  premium_percent = 20
elif (roi> -1 and roi<=-0.90):
  premium_percent = 19
elif (roi> -0.90 and roi<=-0.80):
  premium_percent = 18
elif (roi >-0.80 and roi<=-0.70):
  premium_percent = 17
elif (roi> -0.70 and roi<=-0.60):
  premium_percent = 16
elif (roi> -0.60 and roi<=-0.50):
  premium_percent = 15
elif (roi> -0.50 and roi<=-0.40):
  premium_percent = 14
elif (roi> -0.40 and roi<=-0.30):
  premium_percent = 13
elif (roi> -0.30 and roi<=-0.20):
  premium_percent = 12
elif (roi> -0.20 and roi<=-0.10):
  premium_percent = 11
elif (roi> -0.10 and roi<=0.00):
  premium_percent = 10
elif (roi>0 and roi<=0.10):
  premium_percent = 9
elif (roi>0.10 and roi<=0.20):
  premium_percent = 8
elif (roi>0.20 and roi<=0.20):
  premium_percent = 7
elif (roi>0.30 and roi<=0.40):
  premium_percent = 6
elif (roi>0.40 and roi<=0.50):
  premium_percent = 5   
elif (roi>0.50 and roi<=0.60):
  premium_percent = 4
elif (roi>0.60 and roi<=0.70):
  premium_percent = 3
elif (roi>0.70 and roi<=0.80):
  premium_percent = 2  
elif (roi>0.180 and roi<=0.90):
  premium_percent = 1  
else:
  premium_percent = 0


premium = (premium_percent * funding_aquired_by_startup)/100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 #calc of premium :
#       2 premium_dict = {}
# ----> 3 for startup in listofstartups:
#       4   roi = ((total_invested_money_startup - revenue_generated)/total_invested_money_startup)
#       5   premium_dict[startup] = roi
#
# NameError: name 'listofstartups' is not defined
